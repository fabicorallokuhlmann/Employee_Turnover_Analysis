# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Carregar os dados
desligamento_df = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\desligamentos.xlsx')  # contém Nome da Unidade, % Desligamento Geral, Involuntário, Voluntário
notas_df = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\notas_colaboradores.xlsx')  # contém Nome da Unidade, Liderança, Comunicação, Remuneração, etc.

# 2. Mesclar as bases pela unidade
base_merged = pd.merge(desligamento_df, notas_df, on='Franquia', how='inner')

# 3. Verificar correlação apenas nas colunas numéricas
correlation_matrix = base_merged.select_dtypes(include='number').corr()

# 4. Visualizar correlação dos temas com os desligamentos
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix[['Outra proposta mais atrativa do mercado', 'Incompatibilidade com a gestão', 'Carga de trabalho / Estresse']].dropna().T, 
            annot=True, cmap='coolwarm', center=0)
plt.title('Correlação entre notas e motivos de desligamento')
plt.show()

# Exemplo: Relação entre nota de Liderança e %Desligamento (voluntário)
plt.figure(figsize=(8, 5))
sns.regplot(
    data=base_merged, 
    x='Remuneração e Benefícios', 
    y='Outra proposta mais atrativa do mercado', 
    scatter_kws={'color': 'blue'}, 
    line_kws={'color': 'red'}
)
plt.title('Relação entre Liderança e Desligamento Voluntário')
plt.xlabel('Nota de Liderança')
plt.ylabel('% Desligamento Voluntário')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 import matplotlib.pyplot as plt
#       5 # 1. Carregar os dados
# ----> 6 desligamento_df = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\Pasta15.xlsx - Planilha1.xlsx')  # contém Nome da Unidade, % Desligamento Geral, Involuntário, Voluntário
#       7 notas_df = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\notas_colaboradores.xlsx')  # contém Nome da Unidade, Liderança, Comunicação, Remuneração, etc.
#       9 # 2. Mesclar as bases pela unidade
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Carregar os dados
desligamento_df = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\Planilha sem título (1).xlsx')  # contém Nome da Unidade, % Desligamento Geral, Involuntário, Voluntário
notas_df = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\notas_colaboradores.xlsx')  # contém Nome da Unidade, Liderança, Comunicação, Remuneração, etc.

# 2. Mesclar as bases pela unidade
base_merged = pd.merge(desligamento_df, notas_df, on='Franquia', how='inner')

# Verificar se os dados foram mesclados corretamente
print("Dados mesclados:")
print(base_merged.shape)  # Mostra o número de linhas e colunas
print(base_merged.head())  # Mostra as primeiras linhas dos dados mesclados

# 3. Verificar correlação apenas nas colunas numéricas
correlation_matrix = base_merged.select_dtypes(include='number').corr()

# Verifique se a matriz de correlação contém dados
print("Matriz de correlação:")
print(correlation_matrix)

# 4. Visualizar correlação dos temas com os desligamentos
plt.figure(figsize=(10, 6))
try:
    sns.heatmap(correlation_matrix[['Outra proposta mais atrativa do mercado', 'Incompatibilidade com a gestão', 'Carga de trabalho / Estresse']].dropna().T, 
            annot=True, cmap='coolwarm', center=0)
    plt.title('Correlação entre notas e motivos de desligamento')
    plt.show()
except ValueError as e:
    print(f"Erro ao criar o heatmap: {e}")

# Exemplo: Relação entre nota de Liderança e %Desligamento (voluntário)
plt.figure(figsize=(8, 5))
try:
    sns.regplot(
        data=base_merged, 
        x='Remuneração e Benefícios', 
        y='Carreira e Desenvolvimento', 
        scatter_kws={'color': 'blue'}, 
        line_kws={'color': 'red'}
    )
    plt.title('Relação entre Liderança e Desligamento Voluntário')
    plt.xlabel('Nota de Liderança')
    plt.ylabel('% Desligamento Voluntário')
    plt.grid(True)
    plt.show()
except ValueError as e:
    print(f"Erro ao criar o gráfico de dispersão: {e}")
# Out:
# Dados mesclados:
# (55, 21)
#                            Franquia  Assédio / Denúncia  \
# 0  Omie BA - Unidade SSA Paralela 1                 NaN
# 1  Omie BA - Unidade SSA Salvador 1                 NaN
# 2        Omie DF - Unidade Brasília                 NaN
# 3         Omie ES - Unidade Vitória                 NaN
# 4         Omie GO - Unidade Goiânia                 NaN
#
#    Carga de trabalho / Estresse  Comportamento  Fit Cultural  \
# 0                           NaN         0.1111        0.1333
# 1                           NaN            NaN           NaN
# 2                        0.3333            NaN           NaN
# 3                           NaN            NaN           NaN
# 4                           NaN         0.1111           NaN
#
#    Incompatibilidade com a gestão  Motivos pessoais / familiares  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Carregar os dados
desligamento_df = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\Planilha sem título (1).xlsx')  # contém Nome da Unidade, % Desligamento Geral, Involuntário, Voluntário
notas_df = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\notas_colaboradores.xlsx')  # contém Nome da Unidade, Liderança, Comunicação, Remuneração, etc.

# 2. Mesclar as bases pela unidade
base_merged = pd.merge(desligamento_df, notas_df, on='Franquia', how='inner')

# 3. Verificar correlação apenas nas colunas numéricas
correlation_matrix = base_merged.select_dtypes(include='number').corr()

# 4. Visualizar correlação dos temas com os desligamentos
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix[['Outra proposta mais atrativa do mercado', 'Incompatibilidade com a gestão', 'Carga de trabalho / Estresse']].dropna().T, 
            annot=True, cmap='coolwarm', center=0)
plt.title('Correlação entre notas e motivos de desligamento')
plt.show()

# Exemplo: Relação entre nota de Liderança e %Desligamento (voluntário)
plt.figure(figsize=(8, 5))
sns.regplot(
    data=base_merged, 
    x='Remuneração e Benefícios', 
    y='Outra proposta mais atrativa do mercado', 
    scatter_kws={'color': 'blue'}, 
    line_kws={'color': 'red'}
)
plt.title('Relação entre Liderança e Desligamento Voluntário')
plt.xlabel('Nota de Liderança')
plt.ylabel('% Desligamento Voluntário')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 17
#      15 # 4. Visualizar correlação dos temas com os desligamentos
#      16 plt.figure(figsize=(10, 6))
# ---> 17 sns.heatmap(correlation_matrix[['Outra proposta mais atrativa do mercado', 'Incompatibilidade com a gestão', 'Carga de trabalho / Estresse']].dropna().T,
#      18             annot=True, cmap='coolwarm', center=0)
#      19 plt.title('Correlação entre notas e motivos de desligamento')
#      20 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Carregar os dados
desligamento_df = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\notas_colaboradores.xlsx')   # contém Nome da Unidade, % Desligamento Geral, Involuntário, Voluntário
notas_df = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\Planilha sem título (1).xlsx')    # contém Nome da Unidade, Liderança, Comunicação, Remuneração, etc.

# 2. Mesclar as bases pela unidade
base_merged = pd.merge(desligamento_df, notas_df, on='Franquia')

# 3. Verificar correlação
correlation_matrix = base_merged.corr(numeric_only=True)

# 4. Visualizar correlação dos temas com os desligamentos
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix[['Remuneração e Benefícios', 'Liderança', 'Comunicação', 'Carreira e Desenvolvimento']].dropna().T, 
            annot=True, cmap='coolwarm', center=0)
plt.title('Correlação entre notas e tipos de desligamento')
plt.show()

# Exemplo: Relação entre nota de Liderança e %Desligamento (voluntário)
plt.figure(figsize=(8, 5))
sns.regplot(
    data=base_merged, 
    y='Outra proposta mais atrativa do mercado', 
    x='Remuneração e Benefícios', 
    scatter_kws={'color': 'blue'}, 
    line_kws={'color': 'red'}
)
plt.title('Relação entre Liderança e Desligamento Voluntário')
plt.xlabel('Nota de Liderança')
plt.ylabel('% Desligamento Voluntário')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# === 1. Carregar as bases ===
base_desligamento = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\desligamentos.xlsx')  # Contém: Unidade, Desligamento_Geral, Desligamento_Voluntario, Desligamento_Involuntario
base_notas = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\notas_colaboradores.xlsx')  # Contém: Unidade, Nota_Remuneração, Nota_Liderança, Nota_Comunicação, ...
base_motivos = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\Planilha sem título (1).xlsx')   # Contém: Unidade, Motivo_Proposta_Mercado, Motivo_Gestao, ...

# === 2. Unir as bases ===
df = base_desligamento.merge(base_notas, on="Franquia")
df = df.merge(base_motivos, on="Franquia")

# === 3. Selecionar as colunas de interesse ===
# (ajuste esses nomes conforme os nomes reais das suas colunas)
notas_cols = ['Remuneração e Benefícios', 'Liderança', 'Comunicação']
tipos_desligamento = ['%Desligamento (Geral)', '%Desligamento (voluntário)', '%Desligamento (involuntário)']
motivos_cols = ['Outra proposta mais atrativa do mercado', 'Incompatibilidade com a gestão', 'Comportamento']

# === 4. Calcular matriz de correlação ===
correlation_matrix = df[notas_cols + tipos_desligamento + motivos_cols].corr(method='pearson')

# Correlação entre notas e tipos de desligamento
correlacoes_tipos = correlation_matrix.loc[notas_cols, tipos_desligamento]

# Correlação entre notas e motivos de desligamento
correlacoes_motivos = correlation_matrix.loc[notas_cols, motivos_cols]

# === 5. Visualizar em heatmaps ===
plt.figure(figsize=(10, 6))
sns.heatmap(correlacoes_tipos, annot=True, cmap='coolwarm', center=0)
plt.title("Correlação entre Notas e Tipos de Desligamento")
plt.show()


# Exemplo: Relação entre nota de Liderança e %Desligamento (voluntário)
plt.figure(figsize=(8, 5))
sns.regplot(
    data=base_merged, 
    y='Outra proposta mais atrativa do mercado', 
    x='Remuneração e Benefícios', 
    scatter_kws={'color': 'blue'}, 
    line_kws={'color': 'red'}
)
plt.title('Relação entre Liderança e Desligamento Voluntário')
plt.xlabel('Nota de Liderança')
plt.ylabel('% Desligamento Voluntário')
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))
sns.heatmap(correlacoes_motivos, annot=True, cmap='coolwarm', center=0)
plt.title("Correlação entre Notas e Motivos de Desligamento")
plt.show()

print("Top correlações com desligamento voluntário:")
print(correlacoes_tipos['%Desligamento (voluntário)'].sort_values(key=abs, ascending=False).head())

print("\nTop correlações com motivo 'Proposta mais atrativa':")
print(correlacoes_motivos['Outra proposta mais atrativa do mercado'].sort_values(key=abs, ascending=False).head())
# Out:
# Top correlações com desligamento voluntário:
# Liderança                   0.155942
# Remuneração e Benefícios    0.119894
# Comunicação                 0.061002
# Name: %Desligamento (voluntário), dtype: float64
#
# Top correlações com motivo 'Proposta mais atrativa':
# Remuneração e Benefícios   -0.107380
# Liderança                   0.067176
# Comunicação                 0.020569
# Name: Outra proposta mais atrativa do mercado, dtype: float64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Carregar as bases
notas = pd.read_csv("notas_colaboradores.csv")  # contém 'Unidade', 'Remuneração', 'Liderança', etc.
desligamentos = pd.read_csv("desligamentos.csv")  # contém 'Unidade', '%_Desligamento_Geral', '%_Voluntário', etc.
motivos = pd.read_csv("motivos_desligamento.csv")  # contém 'Unidade', '% Proposta_mercado', '% Gestão', etc.

# Unificar as bases por 'Unidade'
df = notas.merge(desligamentos, on='Unidade')
df = df.merge(motivos, on='Unidade')

# Calcular a correlação
correlation_matrix = df.corr()

# Plotar o heatmap
plt.figure(figsize=(16,10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Matriz de Correlação entre Notas e Desligamentos")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 6
#       3 import matplotlib.pyplot as plt
#       5 # Carregar as bases
# ----> 6 notas = pd.read_csv("notas_colaboradores.csv")  # contém 'Unidade', 'Remuneração', 'Liderança', etc.
#       7 desligamentos = pd.read_csv("desligamentos.csv")  # contém 'Unidade', '%_Desligamento_Geral', '%_Voluntário', etc.
#       8 motivos = pd.read_csv("motivos_desligamento.csv")  # contém 'Unidade', '% Proposta_mercado', '% Gestão', etc.
#
# ...

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree
import matplotlib.pyplot as plt

# === Inputs ===
X = df[notas_cols]  # ex: ['Remuneração e Benefícios', 'Liderança', 'Comunicação']
y = df['%Desligamento (voluntário)']

# === Modelo ===
tree = DecisionTreeRegressor(max_depth=3, random_state=42)
tree.fit(X, y)

# === Visualização ===
plt.figure(figsize=(14, 6))
plot_tree(tree, feature_names=notas_cols, filled=True, rounded=True)
plt.title('Árvore de Decisão - Prevendo % Desligamento Voluntário')
plt.show()

# %%
import statsmodels.api as sm

# === Inputs ===
X = df[notas_cols]
y = df['%Desligamento (voluntário)']

# === Modelo ===
X = sm.add_constant(X)  # Adiciona intercepto
model = sm.OLS(y, X).fit()

# === Resultado ===
print(model.summary())
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     %Desligamento (voluntário)   R-squared:                       0.075
# Model:                                    OLS   Adj. R-squared:                  0.021
# Method:                         Least Squares   F-statistic:                     1.384
# Date:                        Thu, 17 Apr 2025   Prob (F-statistic):              0.258
# Time:                                01:03:38   Log-Likelihood:                 13.170
# No. Observations:                          55   AIC:                            -18.34
# Df Residuals:                              51   BIC:                            -10.31
# Df Model:                                   3
# Covariance Type:                    nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
import seaborn as sns
from scipy.stats import f_oneway
import matplotlib.pyplot as plt
import pandas as pd

# === Criar grupos de desligamento (baixo vs. alto) ===
df['Grupo_Desligamento'] = pd.qcut(df['%Desligamento (voluntário)'], q=2, labels=['Baixo', 'Alto'])

# === Boxplot para comparar distribuição das notas ===
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Grupo_Desligamento', y='Liderança')
plt.title('Nota de Liderança por Grupo de Desligamento Voluntário')
plt.show()

# === ANOVA ===
grupo_alto = df[df['Grupo_Desligamento'] == 'Alto']['Liderança']
grupo_baixo = df[df['Grupo_Desligamento'] == 'Baixo']['Liderança']

f_stat, p_value = f_oneway(grupo_alto, grupo_baixo)
print(f"ANOVA - Nota de Liderança por Grupo de Desligamento Voluntário:\nF = {f_stat:.2f}, p = {p_value:.4f}")
# Out:
# ANOVA - Nota de Liderança por Grupo de Desligamento Voluntário:
# F = 0.15, p = 0.7018

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.cluster import KMeans
import statsmodels.api as sm
from scipy.stats import f_oneway
import warnings
warnings.filterwarnings("ignore")

# === 1. Carregar as bases ===
base_desligamento = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\desligamentos.xlsx')
base_notas = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\notas_colaboradores.xlsx')
base_motivos = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\Planilha sem título (1).xlsx')

# === 2. Unir as bases ===
df = base_desligamento.merge(base_notas, on="Franquia")
df = df.merge(base_motivos, on="Franquia")

# === 3. Selecionar colunas de interesse ===
notas_cols = ['Remuneração e Benefícios', 'Liderança', 'Comunicação']
tipos_desligamento = ['%Desligamento (Geral)', '%Desligamento (voluntário)', '%Desligamento (involuntário)']
motivos_cols = ['Outra proposta mais atrativa do mercado', 'Incompatibilidade com a gestão', 'Comportamento']

# === 4. Matriz de Correlação ===
correlation_matrix = df[notas_cols + tipos_desligamento + motivos_cols].corr(method='pearson')
correlacoes_tipos = correlation_matrix.loc[notas_cols, tipos_desligamento]
correlacoes_motivos = correlation_matrix.loc[notas_cols, motivos_cols]

# === 5. Visualizações ===
plt.figure(figsize=(10, 6))
sns.heatmap(correlacoes_tipos, annot=True, cmap='coolwarm', center=0)
plt.title("Correlação entre Notas e Tipos de Desligamento")
plt.show()

plt.figure(figsize=(12, 6))
sns.heatmap(correlacoes_motivos, annot=True, cmap='coolwarm', center=0)
plt.title("Correlação entre Notas e Motivos de Desligamento")
plt.show()

print("Top correlações com desligamento voluntário:")
print(correlacoes_tipos['%Desligamento (voluntário)'].sort_values(key=abs, ascending=False).head())

print("\nTop correlações com motivo 'Proposta mais atrativa':")
print(correlacoes_motivos['Outra proposta mais atrativa do mercado'].sort_values(key=abs, ascending=False).head())

# === 6. Árvore de Decisão ===
X = df[notas_cols]
y = df['%Desligamento (voluntário)']

tree = DecisionTreeRegressor(max_depth=3, random_state=42)
tree.fit(X, y)

plt.figure(figsize=(14, 6))
plot_tree(tree, feature_names=notas_cols, filled=True, rounded=True)
plt.title('Árvore de Decisão - % Desligamento Voluntário')
plt.show()

# === 7. Regressão Linear ===
X_const = sm.add_constant(X)
model = sm.OLS(y, X_const).fit()
print(model.summary())

# === 8. Agrupamento (KMeans) ===
kmeans = KMeans(n_clusters=2, random_state=42)
df['cluster'] = kmeans.fit_predict(X)

plt.figure(figsize=(8, 6))
sns.scatterplot(x='Remuneração e Benefícios', y='%Desligamento (voluntário)', hue='cluster', data=df, palette='Set2')
plt.title('Clusters com base em Remuneração e % Desligamento Voluntário')
plt.show()

# === 9. Comparação por grupos (ANOVA) ===
df['Grupo_Desligamento'] = pd.qcut(df['%Desligamento (voluntário)'], q=2, labels=['Baixo', 'Alto'])

grupo_alto = df[df['Grupo_Desligamento'] == 'Alto']['Liderança']
grupo_baixo = df[df['Grupo_Desligamento'] == 'Baixo']['Liderança']

f_stat, p_value = f_oneway(grupo_alto, grupo_baixo)
print(f"\nANOVA - Nota de Liderança por Grupo de Desligamento Voluntário:\nF = {f_stat:.2f}, p = {p_value:.4f}")
# Out:
# Top correlações com desligamento voluntário:
# Liderança                   0.155942
# Remuneração e Benefícios    0.119894
# Comunicação                 0.061002
# Name: %Desligamento (voluntário), dtype: float64
#
# Top correlações com motivo 'Proposta mais atrativa':
# Remuneração e Benefícios   -0.107380
# Liderança                   0.067176
# Comunicação                 0.020569
# Name: Outra proposta mais atrativa do mercado, dtype: float64
#                                 OLS Regression Results
# ...
# Dep. Variable:     %Desligamento (voluntário)   R-squared:                       0.075
# Model:                                    OLS   Adj. R-squared:                  0.021
# Method:                         Least Squares   F-statistic:                     1.384
# Date:                        Thu, 17 Apr 2025   Prob (F-statistic):              0.258
# Time:                                01:05:54   Log-Likelihood:                 13.170
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.tree import DecisionTreeRegressor, plot_tree
from scipy.stats import f_oneway

# === 1. Carregar as bases ===
base_desligamento = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\desligamentos.xlsx')
base_notas = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\notas_colaboradores.xlsx')
base_motivos = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\Planilha sem título (1).xlsx')

# === 2. Unir as bases ===
df = base_desligamento.merge(base_notas, on="Franquia")
df = df.merge(base_motivos, on="Franquia")

# === 3. Selecionar colunas de interesse ===
X = df[['Remuneração e Benefícios', 'Liderança']]
y = df['Outra proposta mais atrativa do mercado']

# === 4. Regressão Linear ===
X_const = sm.add_constant(X)
modelo_reg = sm.OLS(y, X_const).fit()
print("\n--- REGRESSÃO LINEAR ---")
print(modelo_reg.summary())

# === 5. Árvore de Decisão ===
tree = DecisionTreeRegressor(max_depth=3, random_state=42)
tree.fit(X, y)

plt.figure(figsize=(12, 6))
plot_tree(tree, feature_names=X.columns, filled=True, rounded=True)
plt.title("Árvore de Decisão: Explicando motivo 'Proposta mais atrativa'")
plt.show()

# === 6. Gráficos de Dispersão com Linha de Tendência ===
sns.lmplot(
    data=df,
    x='Remuneração e Benefícios',
    y='Outra proposta mais atrativa do mercado',
    height=5, aspect=1.5,
    scatter_kws={"s": 60}, line_kws={"color": "red"}
)
plt.title("Remuneração vs Proposta mais atrativa")
plt.show()

sns.lmplot(
    data=df,
    x='Liderança',
    y='Outra proposta mais atrativa do mercado',
    height=5, aspect=1.5,
    scatter_kws={"s": 60}, line_kws={"color": "green"}
)
plt.title("Liderança vs Proposta mais atrativa")
plt.show()

# === 7. ANOVA: Comparar notas entre grupos de motivação ===
# Criar grupos: baixo vs alto motivo
df['Grupo_Proposta'] = pd.qcut(df['Outra proposta mais atrativa do mercado'], q=2, labels=['Baixo', 'Alto'])

# ANOVA para Remuneração
f_stat1, p_val1 = f_oneway(
    df[df['Grupo_Proposta'] == 'Baixo']['Remuneração e Benefícios'],
    df[df['Grupo_Proposta'] == 'Alto']['Remuneração e Benefícios']
)

# ANOVA para Liderança
f_stat2, p_val2 = f_oneway(
    df[df['Grupo_Proposta'] == 'Baixo']['Liderança'],
    df[df['Grupo_Proposta'] == 'Alto']['Liderança']
)

print("\n--- ANOVA ---")
print(f"Remuneração: F = {f_stat1:.2f}, p = {p_val1:.4f}")
print(f"Liderança:    F = {f_stat2:.2f}, p = {p_val2:.4f}")
# Out:
# --- REGRESSÃO LINEAR ---
#                                        OLS Regression Results
# ...
# Dep. Variable:     Outra proposta mais atrativa do mercado   R-squared:                         nan
# Model:                                                 OLS   Adj. R-squared:                    nan
# Method:                                      Least Squares   F-statistic:                       nan
# Date:                                     Thu, 17 Apr 2025   Prob (F-statistic):                nan
# Time:                                             01:09:01   Log-Likelihood:                    nan
# No. Observations:                                       55   AIC:                               nan
# Df Residuals:                                           52   BIC:                               nan
# Df Model:                                                2
# Covariance Type:                                 nonrobust
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.tree import DecisionTreeRegressor, plot_tree
from scipy.stats import f_oneway

# === 1. Carregar as bases ===
base_desligamento = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\desligamentos.xlsx')
base_notas = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\notas_colaboradores.xlsx')
base_motivos = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\Planilha sem título (1).xlsx')

# === 2. Unir as bases ===
df = base_desligamento.merge(base_notas, on="Franquia")
df = df.merge(base_motivos, on="Franquia")

# === 3. Selecionar colunas de interesse ===
X = df[['Remuneração e Benefícios', 'Liderança']]
y = df['Outra proposta mais atrativa do mercado']

# === 4. Remover linhas com NaN em X ou y ===
df_model = df[['Remuneração e Benefícios', 'Liderança', 'Outra proposta mais atrativa do mercado']].dropna()
X = df_model[['Remuneração e Benefícios', 'Liderança']]
y = df_model['Outra proposta mais atrativa do mercado']

# === 5. Regressão Linear ===
X_const = sm.add_constant(X)
modelo_reg = sm.OLS(y, X_const).fit()
print("\n--- REGRESSÃO LINEAR ---")
print(modelo_reg.summary())

# === 6. Árvore de Decisão ===
tree = DecisionTreeRegressor(max_depth=3, random_state=42)
tree.fit(X, y)

plt.figure(figsize=(12, 6))
plot_tree(tree, feature_names=X.columns, filled=True, rounded=True)
plt.title("Árvore de Decisão: Explicando motivo 'Proposta mais atrativa'")
plt.show()

# === 7. Gráficos de Dispersão com Linha de Tendência ===
sns.lmplot(
    data=df_model,
    x='Remuneração e Benefícios',
    y='Outra proposta mais atrativa do mercado',
    height=5, aspect=1.5,
    scatter_kws={"s": 60}, line_kws={"color": "red"}
)
plt.title("Remuneração vs Proposta mais atrativa")
plt.show()

sns.lmplot(
    data=df_model,
    x='Liderança',
    y='Outra proposta mais atrativa do mercado',
    height=5, aspect=1.5,
    scatter_kws={"s": 60}, line_kws={"color": "green"}
)
plt.title("Liderança vs Proposta mais atrativa")
plt.show()

# === 8. ANOVA: Comparar notas entre grupos de motivação ===
df_model['Grupo_Proposta'] = pd.qcut(df_model['Outra proposta mais atrativa do mercado'], q=2, labels=['Baixo', 'Alto'])

# ANOVA para Remuneração
f_stat1, p_val1 = f_oneway(
    df_model[df_model['Grupo_Proposta'] == 'Baixo']['Remuneração e Benefícios'],
    df_model[df_model['Grupo_Proposta'] == 'Alto']['Remuneração e Benefícios']
)

# ANOVA para Liderança
f_stat2, p_val2 = f_oneway(
    df_model[df_model['Grupo_Proposta'] == 'Baixo']['Liderança'],
    df_model[df_model['Grupo_Proposta'] == 'Alto']['Liderança']
)

print("\n--- ANOVA ---")
print(f"Remuneração: F = {f_stat1:.2f}, p = {p_val1:.4f}")
print(f"Liderança:    F = {f_stat2:.2f}, p = {p_val2:.4f}")
# Out:
# --- REGRESSÃO LINEAR ---
#                                        OLS Regression Results
# ...
# Dep. Variable:     Outra proposta mais atrativa do mercado   R-squared:                       0.029
# Model:                                                 OLS   Adj. R-squared:                 -0.046
# Method:                                      Least Squares   F-statistic:                    0.3845
# Date:                                     Thu, 17 Apr 2025   Prob (F-statistic):              0.685
# Time:                                             15:12:01   Log-Likelihood:                -26.985
# No. Observations:                                       29   AIC:                             59.97
# Df Residuals:                                           26   BIC:                             64.07
# Df Model:                                                2
# Covariance Type:                                 nonrobust
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Carregar os dados
desligamento_df = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\OMIE _ Rede de Franquias_ controle de colaboradores_Gerencial_Tabela.xlsx')   # contém Nome da Unidade, % Desligamento Geral, Involuntário, Voluntário
notas_df = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\notas_colaboradores.xlsx')    # contém Nome da Unidade, Liderança, Comunicação, Remuneração, etc.

# 2. Mesclar as bases pela unidade
base_merged = pd.merge(desligamento_df, notas_df, on='Franquia')

# 3. Verificar correlação
correlation_matrix = base_merged.corr(numeric_only=True)

# 4. Visualizar correlação dos temas com os desligamentos
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix[['%Desligamento (Geral)', '%Desligamento (involuntário)', '%Desligamento (voluntário)']].dropna().T, 
            annot=True, cmap='coolwarm', center=0)
plt.title('Correlação entre notas e tipos de desligamento')
plt.show()

# Exemplo: Relação entre nota de Liderança e %Desligamento (voluntário)
plt.figure(figsize=(8, 5))
sns.regplot(
    data=base_merged, 
    x='Liderança', 
    y='%Desligamento (voluntário)', 
    scatter_kws={'color': 'blue'}, 
    line_kws={'color': 'red'}
)
plt.title('Relação entre Liderança e Desligamento Voluntário')
plt.xlabel('Nota de Liderança')
plt.ylabel('% Desligamento Voluntário')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor, plot_tree, export_text
from sklearn.metrics import r2_score
import statsmodels.api as sm
import scipy.stats as stats
import statsmodels.formula.api as smf


# 1. Carregar os dados
desligamento_df = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\desligamentos.xlsx')
notas_df = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\Pasta3.xlsx')

print(desligamento_df.columns)
print(notas_df.columns)

# 2. Mesclar as bases pela unidade
base_merged = pd.merge(desligamento_df, notas_df, on='Franquia')

# 3. Verificar correlação
correlation_matrix = base_merged.corr(numeric_only=True)

# 4. Visualizar correlação dos temas com os desligamentos
plt.figure(figsize=(10, 6))
sns.heatmap(
    correlation_matrix[['%Desligamento (Geral)', '%Desligamento (involuntário)', '%Desligamento (voluntário)']].dropna().T,
    annot=True, cmap='coolwarm', center=0
)
plt.title('Correlação entre notas e tipos de desligamento')
plt.show()

# 5. Gráficos de regressão com R²
colunas_notas = ['Carreira e Desenvolvimento', 'Clima e Colaboração','Comunicação','Diversidade e Inclusão/Compliance',
                 'Engajamento e Cultura', 'Estrutura Organizacional', 'Liderança','Remuneração e Benefícios']  #utilizar os nomes reais


tipo_desligamento = '%Desligamento (voluntário)'  # pode trocar para involuntário ou geral

for coluna in colunas_notas:
    X = base_merged[coluna]
    y = base_merged[tipo_desligamento]

    # Calcular R²
    model = sm.OLS(y, sm.add_constant(X)).fit()
    r2 = model.rsquared

    # Plot
    plt.figure(figsize=(8, 5))
    sns.regplot(x=X, y=y, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
    plt.title(f'{coluna} vs {tipo_desligamento} (R² = {r2:.2f})')
    plt.xlabel(f'Nota de {coluna}')
    plt.ylabel(tipo_desligamento)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# 6. Análise de Variância (ANOVA) - Exemplo com Liderança
# Fórmula para regressão (variável dependente ~ variável independente)
anova_model = smf.ols(f'Q("{tipo_desligamento}") ~ Q("Remuneração e Benefícios")', data=base_merged).fit()
anova_result = sm.stats.anova_lm(anova_model, typ=2)

print("\n--- ANOVA ---")
print(anova_result)

# 7. Árvore de Decisão
X_tree = base_merged[colunas_notas]
y_tree = base_merged[tipo_desligamento]

tree = DecisionTreeRegressor(max_depth=3, random_state=42)
tree.fit(X_tree, y_tree)

#tree = DecisionTreeRegressor(max_depth=3, random_state=42)
#tree.fit(X_tree, y_tree)

# Ver qual nó final cada sample (linha) caiu
base_merged['no_final'] = tree.apply(X_tree)

plt.figure(figsize=(15, 6))
plot_tree(tree, feature_names=colunas_notas, filled=True, rounded=True)
plt.title("Árvore de Decisão - Preditores do Desligamento")
plt.show()

# 8. Regressão Linear Múltipla
X_multi = base_merged[colunas_notas]
X_multi = sm.add_constant(X_multi)
y_multi = base_merged[tipo_desligamento]

modelo_multipla = sm.OLS(y_multi, X_multi).fit()
print("\n--- Regressão Linear Múltipla ---")
print(modelo_multipla.summary())

# Calcular importância das variáveis na árvore
importances = tree.feature_importances_
importancia_df = pd.DataFrame({
    'Variável': colunas_notas,
    'Importância': importances
}).sort_values(by='Importância', ascending=False)

print(importancia_df)

sns.barplot(x='Importância', y='Variável', data=importancia_df)
plt.title('Importância das Variáveis - Árvore de Decisão')
plt.xlabel('Importância (0-1)')
plt.ylabel('Variável')
plt.show()

# Verificar quais unidades caíram em cada nó
#samples_por_no = base_merged.groupby('no_final')['Franquia'].apply(list).reset_index()
#samples_por_no.columns = ['Nó da Árvore', 'Franquias']
#print("\n--- Samples por nó da árvore ---")
#print(samples_por_no)

#samples_por_no.to_excel('samples_por_no.xlsx', index=False)

#tree_rules = export_text(tree, feature_names=colunas_notas)
#print(tree_rules)

# Grupo 1 - Alto desligamento
#grupo_1 = base_merged[
#    (base_merged['Liderança'] <= 9.91) &
  #  (base_merged['Comunicação'] <= 8.27)
#]

# Grupo 2 - Médio-alto desligamento
#grupo_2 = base_merged[
 #   (base_merged['Liderança'] <= 9.91) &
 #  (base_merged['Comunicação'] > 8.27) &
  #  (base_merged['Remuneração e Benefícios'] <= 8.73)
#]

# Grupo 3 - Médio desligamento
#grupo_3 = base_merged[
  #  (base_merged['Liderança'] <= 9.91) &
 #   (base_merged['Comunicação'] > 8.27) &
 #   (base_merged['Remuneração e Benefícios'] > 8.73)
#]

# Grupo 4 - Baixo desligamento
#grupo_4 = base_merged[
   # (base_merged['Liderança'] > 9.91)
#]

#print("\nGrupo 1 - Alto desligamento:")
#print(grupo_1[['Franquia', 'Liderança', 'Comunicação', '%Desligamento (voluntário)']])

#print("\nGrupo 2 - Médio-alto desligamento:")
#print(grupo_2[['Franquia', 'Liderança', 'Comunicação', 'Remuneração e Benefícios', '%Desligamento (voluntário)']])

#print("\nGrupo 3 - Médio desligamento:")
#print(grupo_3[['Franquia', 'Liderança', 'Comunicação', 'Remuneração e Benefícios', '%Desligamento (voluntário)']])

#print("\nGrupo 4 - Baixo desligamento:")
#print(grupo_4[['Franquia', 'Liderança', '%Desligamento (voluntário)']])
# Out:
# Index(['Franquia', '%Desligamento (Geral)', '%Desligamento (involuntário)',
#        '%Desligamento (voluntário)'],
#       dtype='object')
# Index(['Franquia', 'Carreira e Desenvolvimento', 'Clima e Colaboração',
#        'Comunicação', 'Diversidade e Inclusão/Compliance',
#        'Engajamento e Cultura', 'Estrutura Organizacional', 'Liderança',
#        'Remuneração e Benefícios', 'Adesão', 'Teve desligamento?'],
#       dtype='object')
# --- ANOVA ---
#                                  sum_sq    df         F    PR(>F)
# Q("Remuneração e Benefícios")  0.004287   1.0  0.078458  0.781703
# Residual                       1.366097  25.0       NaN       NaN
# --- Regressão Linear Múltipla ---
#                                 OLS Regression Results
# ...
# Dep. Variable:     %Desligamento (voluntário)   R-squared:                       0.497
# Model:                                    OLS   Adj. R-squared:                  0.273
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor, plot_tree, export_text
from sklearn.metrics import r2_score
import statsmodels.api as sm
import scipy.stats as stats
import statsmodels.formula.api as smf


# 1. Carregar os dados
desligamento_df = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\desligamentos.xlsx')
notas_df = pd.read_excel('C:\\Users\\FabianaKuhlmann\\Downloads\\Pasta3.xlsx')

print(desligamento_df.columns)
print(notas_df.columns)

# 2. Mesclar as bases pela unidade
base_merged = pd.merge(desligamento_df, notas_df, on='Franquia')

# 3. Verificar correlação
correlation_matrix = base_merged.corr(numeric_only=True)

# 4. Visualizar correlação dos temas com os desligamentos
plt.figure(figsize=(10, 6))
sns.heatmap(
    correlation_matrix[['%Desligamento (Geral)', '%Desligamento (involuntário)', '%Desligamento (voluntário)']].dropna().T,
    annot=True, cmap='coolwarm', center=0
)
plt.title('Correlação entre notas e tipos de desligamento')
plt.show()

# 5. Gráficos de regressão com R²
colunas_notas = ['Carreira e Desenvolvimento', 'Clima e Colaboração','Comunicação','Diversidade e Inclusão/Compliance',
                 'Engajamento e Cultura', 'Estrutura Organizacional', 'Liderança','Remuneração e Benefícios']  #utilizar os nomes reais


tipo_desligamento = '%Desligamento (voluntário)'  # pode trocar para involuntário ou geral

for coluna in colunas_notas:
    X = base_merged[coluna]
    y = base_merged[tipo_desligamento]

    # Calcular R²
    model = sm.OLS(y, sm.add_constant(X)).fit()
    r2 = model.rsquared

    # Plot
    plt.figure(figsize=(8, 5))
    sns.regplot(x=X, y=y, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
    plt.title(f'{coluna} vs {tipo_desligamento} (R² = {r2:.2f})')
    plt.xlabel(f'Nota de {coluna}')
    plt.ylabel(tipo_desligamento)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# 6. Análise de Variância (ANOVA) - Exemplo com Liderança
# Fórmula para regressão (variável dependente ~ variável independente)
anova_model = smf.ols(f'Q("{tipo_desligamento}") ~ Q("Remuneração e Benefícios")', data=base_merged).fit()
anova_result = sm.stats.anova_lm(anova_model, typ=2)

print("\n--- ANOVA ---")
print(anova_result)

# 7. Árvore de Decisão
X_tree = base_merged[colunas_notas]
y_tree = base_merged[tipo_desligamento]

tree = DecisionTreeRegressor(max_depth=3, random_state=42)
tree.fit(X_tree, y_tree)

#tree = DecisionTreeRegressor(max_depth=3, random_state=42)
#tree.fit(X_tree, y_tree)

# Ver qual nó final cada sample (linha) caiu
base_merged['no_final'] = tree.apply(X_tree)

plt.figure(figsize=(15, 6))
plot_tree(tree, feature_names=colunas_notas, filled=True, rounded=True)
plt.title("Árvore de Decisão - Preditores do Desligamento")
plt.show()

# 8. Regressão Linear Múltipla
X_multi = base_merged[colunas_notas]
X_multi = sm.add_constant(X_multi)
y_multi = base_merged[tipo_desligamento]

modelo_multipla = sm.OLS(y_multi, X_multi).fit()
print("\n--- Regressão Linear Múltipla ---")
print(modelo_multipla.summary())

# Calcular importância das variáveis na árvore
importances = tree.feature_importances_
importancia_df = pd.DataFrame({
    'Variável': colunas_notas,
    'Importância': importances
}).sort_values(by='Importância', ascending=False)

print(importancia_df)

sns.barplot(x='Importância', y='Variável', data=importancia_df)
plt.title('Importância das Variáveis - Árvore de Decisão')
plt.xlabel('Importância (0-1)')
plt.ylabel('Variável')
plt.show()

# Verificar quais unidades caíram em cada nó
#samples_por_no = base_merged.groupby('no_final')['Franquia'].apply(list).reset_index()
#samples_por_no.columns = ['Nó da Árvore', 'Franquias']
#print("\n--- Samples por nó da árvore ---")
#print(samples_por_no)

#samples_por_no.to_excel('samples_por_no.xlsx', index=False)

#tree_rules = export_text(tree, feature_names=colunas_notas)
#print(tree_rules)

# Grupo 1 - Alto desligamento
#grupo_1 = base_merged[
#    (base_merged['Liderança'] <= 9.91) &
  #  (base_merged['Comunicação'] <= 8.27)
#]

# Grupo 2 - Médio-alto desligamento
#grupo_2 = base_merged[
 #   (base_merged['Liderança'] <= 9.91) &
 #  (base_merged['Comunicação'] > 8.27) &
  #  (base_merged['Remuneração e Benefícios'] <= 8.73)
#]

# Grupo 3 - Médio desligamento
#grupo_3 = base_merged[
  #  (base_merged['Liderança'] <= 9.91) &
 #   (base_merged['Comunicação'] > 8.27) &
 #   (base_merged['Remuneração e Benefícios'] > 8.73)
#]

# Grupo 4 - Baixo desligamento
#grupo_4 = base_merged[
   # (base_merged['Liderança'] > 9.91)
#]

#print("\nGrupo 1 - Alto desligamento:")
#print(grupo_1[['Franquia', 'Liderança', 'Comunicação', '%Desligamento (voluntário)']])

#print("\nGrupo 2 - Médio-alto desligamento:")
#print(grupo_2[['Franquia', 'Liderança', 'Comunicação', 'Remuneração e Benefícios', '%Desligamento (voluntário)']])

#print("\nGrupo 3 - Médio desligamento:")
#print(grupo_3[['Franquia', 'Liderança', 'Comunicação', 'Remuneração e Benefícios', '%Desligamento (voluntário)']])

#print("\nGrupo 4 - Baixo desligamento:")
#print(grupo_4[['Franquia', 'Liderança', '%Desligamento (voluntário)']])


# 7. Árvore de Decisão por unidade

# 7. Árvore de Decisão geral
X_tree = base_merged[colunas_notas]
y_tree = base_merged[tipo_desligamento]

tree = DecisionTreeRegressor(max_depth=3, random_state=42)
tree.fit(X_tree, y_tree)

# Ver qual nó cada unidade caiu
base_merged['no_final'] = tree.apply(X_tree)

plt.figure(figsize=(15, 6))
plot_tree(tree, feature_names=colunas_notas, filled=True, rounded=True)
plt.title("Árvore de Decisão - Preditores do Desligamento")
plt.show()

# Mostrar unidades por nó
samples_por_no = base_merged.groupby('no_final')['Franquia'].apply(list).reset_index()
samples_por_no.columns = ['Nó da Árvore', 'Franquias']
print("\n--- Unidades por nó da árvore ---")
print(samples_por_no)
# Out:
# Index(['Franquia', '%Desligamento (Geral)', '%Desligamento (involuntário)',
#        '%Desligamento (voluntário)'],
#       dtype='object')
# Index(['Franquia', 'Carreira e Desenvolvimento', 'Clima e Colaboração',
#        'Comunicação', 'Diversidade e Inclusão/Compliance',
#        'Engajamento e Cultura', 'Estrutura Organizacional', 'Liderança',
#        'Remuneração e Benefícios', 'Adesão', 'Teve desligamento?'],
#       dtype='object')
# --- ANOVA ---
#                                  sum_sq    df         F    PR(>F)
# Q("Remuneração e Benefícios")  0.004287   1.0  0.078458  0.781703
# Residual                       1.366097  25.0       NaN       NaN
# --- Regressão Linear Múltipla ---
#                                 OLS Regression Results
# ...
# Dep. Variable:     %Desligamento (voluntário)   R-squared:                       0.497
# Model:                                    OLS   Adj. R-squared:                  0.273
# ...
